# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline
np.random.seed(42)

# %%
df = pd.read_csv('../data/USAverage_Energy_CO2_1970to2021.csv')

# %%
df.head()
# Out:
#    Year  CO2_Value     Coal_Value  Natural_Gas_Value  Nuclear_Energy_Value  \
# 0  1970  21.733333  240566.529412      425347.294118           4693.098039
# 1  1971  21.880392  227513.745098      438534.254902           8096.843137
# 2  1972  22.996078  237441.764706      444754.823529          11446.098039
# 3  1973  23.625490  254119.980392      443045.960784          17846.627451
# 4  1974  22.750980  248058.960784      426069.764706          24942.843137
#
#    Petroleum_Energy_Value  Renewable_Energy_Value
# 0           578433.607843            79804.333333
# 1           598852.058824            83572.745098
# 2           645473.647059            85921.686275
# 3           682471.156863            86489.039216
# 4           655306.156863            92977.490196

# %%
df.set_index("Year", inplace=True)

# %%
df.head()
# Out:
#       CO2_Value     Coal_Value  Natural_Gas_Value  Nuclear_Energy_Value  \
# Year
# 1970  21.733333  240566.529412      425347.294118           4693.098039
# 1971  21.880392  227513.745098      438534.254902           8096.843137
# 1972  22.996078  237441.764706      444754.823529          11446.098039
# 1973  23.625490  254119.980392      443045.960784          17846.627451
# 1974  22.750980  248058.960784      426069.764706          24942.843137
#
#       Petroleum_Energy_Value  Renewable_Energy_Value
# Year
# 1970           578433.607843            79804.333333
# 1971           598852.058824            83572.745098
# 1972           645473.647059            85921.686275
# 1973           682471.156863            86489.039216
# 1974           655306.156863            92977.490196

# %%
df.columns = df.columns.str.lower()

# %%
df.columns = df.columns.str.replace("_value","")

# %%
df.columns = df.columns.str.replace("_energy","")

# %%
df.head()
# Out:
#             co2           coal    natural_gas       nuclear      petroleum  \
# Year
# 1970  21.733333  240566.529412  425347.294118   4693.098039  578433.607843
# 1971  21.880392  227513.745098  438534.254902   8096.843137  598852.058824
# 1972  22.996078  237441.764706  444754.823529  11446.098039  645473.647059
# 1973  23.625490  254119.980392  443045.960784  17846.627451  682471.156863
# 1974  22.750980  248058.960784  426069.764706  24942.843137  655306.156863
#
#          renewable
# Year
# 1970  79804.333333
# 1971  83572.745098
# 1972  85921.686275
# 1973  86489.039216
# 1974  92977.490196

# %%
def plot_series(df, cols=None, title='Title', xlab=None, ylab=None, steps=1):
    
    # Set figure size to be (18, 9).
    plt.figure(figsize=(18,9))
    
    # Iterate through each column name.
    for col in cols:
            
        # Generate a line plot of the column name.
        # You only have to specify Y, since our
        # index will be a datetime index.
        plt.plot(df[col])
        
    # Generate title and labels.
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.yticks(fontsize=18)
    plt.xticks(df.index[0::steps], fontsize=18);

# %%
plot_series(df, ['co2'], title="CO2 Values", ylab="CO2 emissions per capita, metric tons",  steps=5)
plt.savefig("../vis/co2_dom.png");

# %% [markdown]
# CO2 emissions seem to dip during energy crisis of late 1970s and early 1980s, and significant decreases since mid to late 2000s,\
# followed by an exceptionally large dip in 2020, followed by the beginning of a rebound in post-COVID era.

# %%
plot_series(df, ['coal'], title="Coal Values", ylab="Consumption, billion BTU", steps=5)
plt.savefig("../vis/coal_dom.png");

# %% [markdown]
# Significant coal divestment from late 2000s on

# %%
plot_series(df, ['natural_gas'], title="Natural Gas Values", ylab="Consumption, billion BTU", steps=5)
plt.savefig("../vis/natural_gas_dom.png");

# %% [markdown]
# Drastic increases in energy production from natural gas began occurring in the 2000s.

# %%
plot_series(df, ['nuclear'], title="Nuclear Energy Values", ylab="Consumption, billion BTU", steps=5)
plt.savefig("../vis/nuclear_dom.png");

# %%
plot_series(df, ['petroleum'], title="Petroleum Energy Values", ylab="Consumption, billion BTU", steps=5)
plt.savefig("../vis/petroleum_dom.png");

# %% [markdown]
# Sharp decrease in consumption of oil-produced energy in the early 1980s likely due to sharp increase in price of oil during this time period.

# %%
plot_series(df, ['renewable'], title="Renewable Energy Values", ylab="Consumption, billion BTU", steps=5)
plt.savefig("../vis/renewable_dom.png");

# %% [markdown]
# Wind energy production began to climb drastically in the early 2000s, 2010-2020 saw continued growth in wind and more drastic growth in solar production.

# %%
def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:2], index=['Test Statistic','p-value'])
    return dfoutput

# %% [markdown]
# Test for p-values using an ADF test until p is lower than .05 to established stationarity.

# %%
interpret_dftest(adfuller(df['co2']))
# Out:
# Test Statistic   -2.034696
# p-value           0.271570
# dtype: float64

# %%
interpret_dftest(adfuller(df['co2'].diff().dropna()))
# Out:
# Test Statistic   -3.645985
# p-value           0.004940
# dtype: float64

# %%
interpret_dftest(adfuller(df['coal']))
# Out:
# Test Statistic   -2.208249
# p-value           0.203265
# dtype: float64

# %%
interpret_dftest(adfuller(df['coal'].diff().dropna()))
# Out:
# Test Statistic    0.544552
# p-value           0.986166
# dtype: float64

# %%
interpret_dftest(adfuller(df['coal'].diff().diff().dropna()))
# Out:
# Test Statistic   -7.470247e+00
# p-value           5.077202e-11
# dtype: float64

# %%
interpret_dftest(adfuller(df['natural_gas']))
# Out:
# Test Statistic    0.945477
# p-value           0.993656
# dtype: float64

# %%
interpret_dftest(adfuller(df['natural_gas'].diff().dropna()))
# Out:
# Test Statistic   -6.328106e+00
# p-value           2.951961e-08
# dtype: float64

# %%
interpret_dftest(adfuller(df['nuclear']))
# Out:
# Test Statistic   -3.416778
# p-value           0.010400
# dtype: float64

# %% [markdown]
# Nuclear is the only feature that required no differencing in order to achieve stationarity.

# %%
interpret_dftest(adfuller(df['petroleum']))
# Out:
# Test Statistic   -2.486266
# p-value           0.118852
# dtype: float64

# %%
interpret_dftest(adfuller(df['petroleum'].diff().dropna()))
# Out:
# Test Statistic   -5.332416
# p-value           0.000005
# dtype: float64

# %%
interpret_dftest(adfuller(df['renewable']))
# Out:
# Test Statistic    1.130740
# p-value           0.995471
# dtype: float64

# %%
interpret_dftest(adfuller(df['renewable'].diff().dropna()))
# Out:
# Test Statistic   -6.696366e+00
# p-value           3.990237e-09
# dtype: float64

# %%
df['first_diff_co2'] = df['co2'].diff()

# %%
df['second_diff_coal'] = df['coal'].diff().diff()

# %%
df['first_diff_natural_gas'] = df['natural_gas'].diff()

# %%
df['first_diff_petroleum'] = df['petroleum'].diff()

# %%
df['first_diff_renewable'] = df['renewable'].diff()

# %%
df.head()
# Out:
#             co2           coal    natural_gas       nuclear      petroleum  \
# Year
# 1970  21.733333  240566.529412  425347.294118   4693.098039  578433.607843
# 1971  21.880392  227513.745098  438534.254902   8096.843137  598852.058824
# 1972  22.996078  237441.764706  444754.823529  11446.098039  645473.647059
# 1973  23.625490  254119.980392  443045.960784  17846.627451  682471.156863
# 1974  22.750980  248058.960784  426069.764706  24942.843137  655306.156863
#
#          renewable  first_diff_co2  second_diff_coal  first_diff_natural_gas  \
# Year
# 1970  79804.333333             NaN               NaN                     NaN
# 1971  83572.745098        0.147059               NaN            13186.960784
# 1972  85921.686275        1.115686      22980.803922             6220.568627
# 1973  86489.039216        0.629412       6750.196078            -1708.862745
# 1974  92977.490196       -0.874510     -22739.235294           -16976.196078
#
#       first_diff_petroleum  first_diff_renewable
# Year
# 1970                   NaN                   NaN
# 1971          20418.450980           3768.411765
# 1972          46621.588235           2348.941176
# 1973          36997.509804            567.352941
# 1974         -27165.000000           6488.450980

# %%
df = df[['first_diff_co2','second_diff_coal','first_diff_natural_gas','nuclear','first_diff_petroleum','first_diff_renewable']]

df.dropna(inplace=True)

# %% [markdown]
# Created a subset of the original dataset which consists of all of the variables being tested in the multivariate time series model after achieving stationarity.

# %%
train, test = train_test_split(df, test_size = 0.2, shuffle=False)

# %%
model = VAR(train)
# Out:
# c:\Users\domin.DESKTOP-S15RK6B\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
ts_model = model.fit(maxlags=4,
                     ic = 'aic')

# %%
ts_model.k_ar
# Out:
# 4

# %%
ts_model.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 19, Feb, 2024
# Time:                     11:59:58
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                    93.5335
# Nobs:                     36.0000    HQIC:                   89.2384
# Log likelihood:          -1721.33    FPE:                3.98209e+38
# AIC:                      86.9355    Det(Omega_mle):     1.68247e+37
# --------------------------------------------------------------------
# Results for equation first_diff_co2
# ============================================================================================
#                                coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------
# const                             0.254084         0.764781            0.332           0.740
# L1.first_diff_co2                -0.674921         1.008984           -0.669           0.504
# L1.second_diff_coal              -0.000002         0.000017           -0.128           0.898
# L1.first_diff_natural_gas         0.000009         0.000026            0.348           0.728
# L1.nuclear                       -0.000011         0.000050           -0.215           0.829
# L1.first_diff_petroleum           0.000027         0.000022            1.221           0.222
# L1.first_diff_renewable           0.000004         0.000029            0.124           0.902
# L2.first_diff_co2                 1.244750         1.300007            0.957           0.338
# L2.second_diff_coal              -0.000004         0.000027           -0.142           0.887
# L2.first_diff_natural_gas        -0.000040         0.000020           -2.010           0.044
# L2.nuclear                        0.000022         0.000056            0.388           0.698
# L2.first_diff_petroleum          -0.000032         0.000034           -0.944           0.345
# L2.first_diff_renewable           0.000002         0.000019            0.109           0.913
# L3.first_diff_co2                -0.958383         0.840025           -1.141           0.254
# L3.second_diff_coal               0.000021         0.000026            0.807           0.419
# L3.first_diff_natural_gas         0.000006         0.000028            0.229           0.819
# L3.nuclear                       -0.000001         0.000043           -0.023           0.982
# L3.first_diff_petroleum           0.000028         0.000020            1.384           0.166
# L3.first_diff_renewable          -0.000015         0.000020           -0.768           0.442
# L4.first_diff_co2                 0.908476         0.713147            1.274           0.203
# L4.second_diff_coal              -0.000001         0.000020           -0.065           0.948
# L4.first_diff_natural_gas         0.000023         0.000023            1.000           0.317
# L4.nuclear                       -0.000013         0.000033           -0.375           0.708
# L4.first_diff_petroleum          -0.000027         0.000012           -2.201           0.028
# L4.first_diff_renewable          -0.000008         0.000023           -0.349           0.727
# ============================================================================================
#
# Results for equation second_diff_coal
# ============================================================================================
#                                coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------
# const                         38450.452848     13866.225519            2.773           0.006
# L1.first_diff_co2            -48362.331442     18293.851073           -2.644           0.008
# L1.second_diff_coal              -1.203938         0.299680           -4.017           0.000
# L1.first_diff_natural_gas         1.358834         0.463554            2.931           0.003
# L1.nuclear                       -2.419745         0.897915           -2.695           0.007
# L1.first_diff_petroleum           1.418046         0.404367            3.507           0.000
# L1.first_diff_renewable          -0.165644         0.529335           -0.313           0.754
# L2.first_diff_co2             51627.633136     23570.382208            2.190           0.028
# L2.second_diff_coal              -1.283873         0.483359           -2.656           0.008
# L2.first_diff_natural_gas        -0.842273         0.363103           -2.320           0.020
# L2.nuclear                        1.907360         1.020351            1.869           0.062
# L2.first_diff_petroleum          -1.639519         0.617554           -2.655           0.008
# L2.first_diff_renewable          -0.190949         0.352574           -0.542           0.588
# L3.first_diff_co2            -11863.710888     15230.467795           -0.779           0.436
# L3.second_diff_coal               0.104359         0.465805            0.224           0.823
# L3.first_diff_natural_gas        -1.084895         0.513754           -2.112           0.035
# L3.nuclear                       -0.313683         0.772674           -0.406           0.685
# L3.first_diff_petroleum           0.955250         0.367889            2.597           0.009
# L3.first_diff_renewable          -0.050251         0.353933           -0.142           0.887
# L4.first_diff_co2              8332.672613     12930.048736            0.644           0.519
# L4.second_diff_coal               0.027064         0.364098            0.074           0.941
# L4.first_diff_natural_gas         1.028955         0.422466            2.436           0.015
# L4.nuclear                        0.586187         0.607272            0.965           0.334
# L4.first_diff_petroleum          -0.550139         0.219177           -2.510           0.012
# L4.first_diff_renewable          -1.029357         0.423032           -2.433           0.015
# ============================================================================================
#
# Results for equation first_diff_natural_gas
# ============================================================================================
#                                coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------
# const                         11824.033868     20812.213594            0.568           0.570
# L1.first_diff_co2            -39043.319389     27457.763142           -1.422           0.155
# L1.second_diff_coal              -0.086572         0.449799           -0.192           0.847
# L1.first_diff_natural_gas         0.786631         0.695761            1.131           0.258
# L1.nuclear                       -0.227385         1.347707           -0.169           0.866
# L1.first_diff_petroleum           1.046991         0.606926            1.725           0.085
# L1.first_diff_renewable          -0.135774         0.794494           -0.171           0.864
# L2.first_diff_co2             33965.820640     35377.459304            0.960           0.337
# L2.second_diff_coal              -0.774579         0.725487           -1.068           0.286
# L2.first_diff_natural_gas        -0.133895         0.544991           -0.246           0.806
# L2.nuclear                       -0.744229         1.531473           -0.486           0.627
# L2.first_diff_petroleum          -0.888415         0.926904           -0.958           0.338
# L2.first_diff_renewable          -0.108071         0.529188           -0.204           0.838
# L3.first_diff_co2              1929.621356     22859.843759            0.084           0.933
# L3.second_diff_coal              -0.735457         0.699140           -1.052           0.293
# L3.first_diff_natural_gas        -0.441743         0.771108           -0.573           0.567
# L3.nuclear                        0.792550         1.159728            0.683           0.494
# L3.first_diff_petroleum           0.410840         0.552175            0.744           0.457
# L3.first_diff_renewable          -0.002808         0.531229           -0.005           0.996
# L4.first_diff_co2              7872.909384     19407.079144            0.406           0.685
# L4.second_diff_coal              -0.106324         0.546484           -0.195           0.846
# L4.first_diff_natural_gas         0.173099         0.634092            0.273           0.785
# L4.nuclear                        0.121251         0.911472            0.133           0.894
# L4.first_diff_petroleum          -0.297476         0.328969           -0.904           0.366
# L4.first_diff_renewable           0.079353         0.634940            0.125           0.901
# ============================================================================================
#
# Results for equation nuclear
# ============================================================================================
#                                coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------
# const                          4754.537462      7950.628344            0.598           0.550
# L1.first_diff_co2              -344.893965     10489.344102           -0.033           0.974
# L1.second_diff_coal               0.032205         0.171831            0.187           0.851
# L1.first_diff_natural_gas        -0.034493         0.265793           -0.130           0.897
# L1.nuclear                        1.201751         0.514848            2.334           0.020
# L1.first_diff_petroleum          -0.001815         0.231856           -0.008           0.994
# L1.first_diff_renewable          -0.103702         0.303511           -0.342           0.733
# L2.first_diff_co2              5652.834182     13514.806074            0.418           0.676
# L2.second_diff_coal               0.142780         0.277149            0.515           0.606
# L2.first_diff_natural_gas        -0.180925         0.208196           -0.869           0.385
# L2.nuclear                       -0.705383         0.585049           -1.206           0.228
# L2.first_diff_petroleum           0.035825         0.354093            0.101           0.919
# L2.first_diff_renewable           0.084865         0.202159            0.420           0.675
# L3.first_diff_co2              5585.761237      8732.858757            0.640           0.522
# L3.second_diff_coal              -0.040594         0.267084           -0.152           0.879
# L3.first_diff_natural_gas         0.051265         0.294577            0.174           0.862
# L3.nuclear                        0.547759         0.443036            1.236           0.216
# L3.first_diff_petroleum          -0.245772         0.210940           -1.165           0.244
# L3.first_diff_renewable          -0.170256         0.202939           -0.839           0.401
# L4.first_diff_co2              3791.325075      7413.842494            0.511           0.609
# L4.second_diff_coal               0.023187         0.208767            0.111           0.912
# L4.first_diff_natural_gas        -0.045847         0.242234           -0.189           0.850
# L4.nuclear                       -0.043530         0.348198           -0.125           0.901
# L4.first_diff_petroleum           0.040967         0.125672            0.326           0.744
# L4.first_diff_renewable           0.206655         0.242558            0.852           0.394
# ============================================================================================
#
# Results for equation first_diff_petroleum
# ============================================================================================
#                                coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------
# const                        -28989.613163     27767.750701           -1.044           0.296
# L1.first_diff_co2            -10618.937200     36634.273347           -0.290           0.772
# L1.second_diff_coal               0.110491         0.600123            0.184           0.854
# L1.first_diff_natural_gas        -0.492093         0.928287           -0.530           0.596
# L1.nuclear                        1.285218         1.798117            0.715           0.475
# L1.first_diff_petroleum           0.796802         0.809763            0.984           0.325
# L1.first_diff_renewable           0.857852         1.060018            0.809           0.418
# L2.first_diff_co2              3541.102243     47200.768240            0.075           0.940
# L2.second_diff_coal               0.906379         0.967948            0.936           0.349
# L2.first_diff_natural_gas        -0.731883         0.727129           -1.007           0.314
# L2.nuclear                        0.341164         2.043299            0.167           0.867
# L2.first_diff_petroleum          -0.270989         1.236679           -0.219           0.827
# L2.first_diff_renewable           0.137057         0.706045            0.194           0.846
# L3.first_diff_co2            -46600.151977     30499.708246           -1.528           0.127
# L3.second_diff_coal               1.677251         0.932795            1.798           0.072
# L3.first_diff_natural_gas         0.526957         1.028816            0.512           0.609
# L3.nuclear                        0.000110         1.547314            0.000           1.000
# L3.first_diff_petroleum           0.656796         0.736714            0.892           0.373
# L3.first_diff_renewable          -0.617444         0.708768           -0.871           0.384
# L4.first_diff_co2             42090.054628     25893.013883            1.626           0.104
# L4.second_diff_coal               0.087434         0.729122            0.120           0.905
# L4.first_diff_natural_gas         0.682641         0.846008            0.807           0.420
# L4.nuclear                       -1.495091         1.216090           -1.229           0.219
# L4.first_diff_petroleum          -0.963040         0.438912           -2.194           0.028
# L4.first_diff_renewable           0.154687         0.847141            0.183           0.855
# ============================================================================================
#
# Results for equation first_diff_renewable
# ============================================================================================
#                                coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------
# const                         19375.386755     11562.205567            1.676           0.094
# L1.first_diff_co2             -1559.941768     15254.134329           -0.102           0.919
# L1.second_diff_coal              -0.433117         0.249885           -1.733           0.083
# L1.first_diff_natural_gas         0.263825         0.386529            0.683           0.495
# L1.nuclear                       -0.543622         0.748717           -0.726           0.468
# L1.first_diff_petroleum           0.227838         0.337177            0.676           0.499
# L1.first_diff_renewable           0.011865         0.441380            0.027           0.979
# L2.first_diff_co2             -7370.382655     19653.914038           -0.375           0.708
# L2.second_diff_coal              -0.657417         0.403044           -1.631           0.103
# L2.first_diff_natural_gas         0.604657         0.302769            1.997           0.046
# L2.nuclear                       -0.133987         0.850809           -0.157           0.875
# L2.first_diff_petroleum          -0.102634         0.514941           -0.199           0.842
# L2.first_diff_renewable          -0.175569         0.293990           -0.597           0.550
# L3.first_diff_co2             -3429.259950     12699.764567           -0.270           0.787
# L3.second_diff_coal               0.080481         0.388406            0.207           0.836
# L3.first_diff_natural_gas        -0.509911         0.428388           -1.190           0.234
# L3.nuclear                        0.080181         0.644286            0.124           0.901
# L3.first_diff_petroleum           0.059576         0.306760            0.194           0.846
# L3.first_diff_renewable          -0.011657         0.295124           -0.039           0.968
# L4.first_diff_co2              -451.814519     10781.584453           -0.042           0.967
# L4.second_diff_coal              -0.026868         0.303599           -0.088           0.929
# L4.first_diff_natural_gas        -0.092251         0.352269           -0.262           0.793
# L4.nuclear                        0.497952         0.506367            0.983           0.325
# L4.first_diff_petroleum           0.018370         0.182759            0.101           0.920
# L4.first_diff_renewable          -0.507295         0.352741           -1.438           0.150
# ============================================================================================
#
# Correlation matrix of residuals
#                           first_diff_co2  second_diff_coal  first_diff_natural_gas   nuclear  first_diff_petroleum  first_diff_renewable
# first_diff_co2                  1.000000          0.475119                0.469484  0.666117              0.764596             -0.329740
# second_diff_coal                0.475119          1.000000                0.136770  0.021665              0.127635             -0.158019
# first_diff_natural_gas          0.469484          0.136770                1.000000  0.427992             -0.055230              0.445789
# nuclear                         0.666117          0.021665                0.427992  1.000000              0.695670             -0.388864
# first_diff_petroleum            0.764596          0.127635               -0.055230  0.695670              1.000000             -0.691406
# first_diff_renewable           -0.329740         -0.158019                0.445789 -0.388864             -0.691406              1.000000

# %%
ts_model.plot();

# %%
ts_model.plot_forecast(5)
plt.savefig("../vis/multivariateplot.png");

# %% [markdown]
# CO2 emissions forecasted to increase slightly in post-COVID era, followed by continued downward trend.

# %%
forecast = ts_model.forecast(train.values, len(test))

# %%
for i in range(test.shape[1]):
    print(f"The test RMSE on the {test.columns[i]} data is: \
          {(mean_squared_error(test.values[:,i], forecast[:, i]))**.5}")
# Out:
# The test RMSE on the first_diff_co2 data is:           1.7407877621331642
# The test RMSE on the second_diff_coal data is:           157777.97996308003
# The test RMSE on the first_diff_natural_gas data is:           34779.948212240575
# The test RMSE on the nuclear data is:           17989.922876261444
# The test RMSE on the first_diff_petroleum data is:           63008.63853734997
# The test RMSE on the first_diff_renewable data is:           83886.77771911769
