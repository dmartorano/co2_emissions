# %% [markdown]
# #### Import Libraries and Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning);

# %% [markdown]
# #### Read in Data

# %%
df_USA_renewables = pd.read_csv('/Users/ben/Desktop/DSI_GA_Materials/project_5/data/df_USA_cleaned.csv')

# %%
df_poll_to_2023 = pd.read_csv('../data/pollution_2000_2023.csv')

# %%
USAverage_Energy_CO2_1970to2021 = pd.read_csv('../data/USAverage_Energy_CO2_1970to2021.csv')

# %%
df_USA_renewables.set_index('Year',inplace=True)

# %%
df_poll_to_2023['Date'] = pd.to_datetime(df_poll_to_2023['Date'])
df_poll_to_2023.set_index('Date',inplace=True)
df_poll_to_2023.drop(columns=["Unnamed: 0", "Address","County", "City"], inplace=True)
df_poll_to_2023
# Out:
#               State   O3 Mean  O3 1st Max Value  O3 1st Max Hour  O3 AQI  \
# Date
# 2000-01-01  Arizona  0.019765             0.040               10      37
# 2000-01-02  Arizona  0.015882             0.032               10      30
# 2000-01-03  Arizona  0.009353             0.016                9      15
# 2000-01-04  Arizona  0.015882             0.033                9      31
# 2000-01-05  Arizona  0.007353             0.012                9      11
# ...             ...       ...               ...              ...     ...
# 2023-06-26  Wyoming  0.043941             0.050               12      46
# 2023-06-27  Wyoming  0.046235             0.054               12      50
# 2023-06-28  Wyoming  0.046588             0.055                7      51
# 2023-06-29  Wyoming  0.048765             0.056                9      54
# 2023-06-30  Wyoming  0.048333             0.051                7      47
#
#              CO Mean  CO 1st Max Value  CO 1st Max Hour  CO AQI  SO2 Mean  \
# Date
# ...

# %%
USAverage_Energy_CO2_1970to2021.set_index('Year',inplace=True)

# %%
USAverage_Energy_CO2_1970to2021
# Out:
#       CO2_Value     Coal_Value  Natural_Gas_Value  Nuclear_Energy_Value  \
# Year
# 1970  21.733333  240566.529412      425347.294118           4693.098039
# 1971  21.880392  227513.745098      438534.254902           8096.843137
# 1972  22.996078  237441.764706      444754.823529          11446.098039
# 1973  23.625490  254119.980392      443045.960784          17846.627451
# 1974  22.750980  248058.960784      426069.764706          24942.843137
# 1975  22.023529  248149.313725      391707.392157          37250.941176
# 1976  23.354902  266193.901961      399631.921569          41394.509804
# 1977  24.007843  272688.450980      391617.235294          52975.686275
# 1978  23.898039  269993.823529      393483.588235          59296.588235
# 1979  24.007843  294934.313725      405639.568627          54428.019608
# 1980  22.888235  303156.568627      396606.647059          53709.215686
# 1981  22.327451  312504.470588      387247.490196          58972.313725
# ...

# %%
def plot_series(df, cols=None, title='Title', xlab=None, ylab=None):
    
    # Set figure size to be (18, 9).
    plt.figure(figsize=(18,9))
    
    # Iterate through each column name.
    for col in cols:
        
        # Generate a line plot of the column name.
        # You only have to specify Y, since our
        # index will be a datetime index.
        plt.plot(df[col])
        
    # Generate title and labels.
    plt.title(title, fontsize=26)
    plt.xlabel(xlab, fontsize=20)
    plt.ylabel(ylab, fontsize=20)
    
    # Enlarge tick marks.
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18);

# %% [markdown]
# #### Plot Renewable Variables of Interest

# %%
# ['Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)','Electricity from renewables (TWh)']

# %%
plot_series(df_USA_renewables, cols = ['Electricity from fossil fuels (TWh)'], title = 'Change in Electricity from fossil fuels (TWh)')

# %%
plot_series(df_USA_renewables, cols = ['Electricity from nuclear (TWh)'], title = 'Change in Electricity from nuclear (TWh)')

# %%
plot_series(df_USA_renewables, cols = ['Electricity from renewables (TWh)'], title = 'Change in Electricity from renewables (TWh)')

# %% [markdown]
# #### Plot Mean Air Pollution Values and Other Metrics
#
# Do this to gain insights into trends of data.

# %%
df_poll_to_2023.columns
# Out:
# Index(['State', 'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI',
#        'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI', 'SO2 Mean',
#        'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI'],
#       dtype='object')

# %%
plot_series(df_poll_to_2023, cols = ['O3 Mean'], title = 'Change in O3 Mean')

# %%
plot_series(df_poll_to_2023, cols = ['CO Mean'], title = 'Change in CO Mean')

# %%
plot_series(df_poll_to_2023, cols = ['SO2 Mean'], title = 'Change in SO2 Mean')

# %% [markdown]
# #### Veniaminof	United States	2006 Mar 3
# Cause spike in SO2 detected by multiple states in the continental US

# %%
plot_series(df_poll_to_2023, cols = ['NO2 Mean'], title = 'Change in NO2 Mean')

# %% [markdown]
# #### Coronavirus Pandemic
# Cause spike in NO2 detected by multiple states in the continental US

# %%
#### Air Quality Indices

# %%
plot_series(df_poll_to_2023, cols = ['O3 AQI'], title = 'Change in O3 AQI')

# %%
plot_series(df_poll_to_2023, cols = ['CO AQI'], title = 'Change in CO AQI')

# %%
plot_series(df_poll_to_2023, cols = ['SO2 AQI'], title = 'Change in SO2 AQI')

# %%
plot_series(df_poll_to_2023, cols = ['NO2 AQI'], title = 'Change in NO2 AQI')
